# %% [markdown]
# <h2>Required Libraries :-</h2>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
import joblib
import os

# %%
df = pd.read_csv('Data.csv')
df
# Out:
#             State         District                   Market      Commodity  \
# 0           Bihar           Araria               Forbesganj         Potato
# 1           Bihar       Kishanganj              Bahadurganj         Potato
# 2           Bihar        Madhubani                 Jainagar          Onion
# 3           Bihar           Rohtas                   Natwar         Potato
# 4      Chandigarh       Chandigarh  Chandigarh(Grain/Fruit)  Ginger(Green)
# ...           ...              ...                      ...            ...
# 7934  West Bengal  Purba Bardhaman                    Kalna   Green Chilli
# 7935  West Bengal  Purba Bardhaman                    Kalna  Sweet Pumpkin
# 7936  West Bengal  Purba Bardhaman                   Memari        Brinjal
# 7937  West Bengal  Purba Bardhaman                   Memari  Sweet Pumpkin
# 7938  West Bengal         Puruliya                  Purulia         Potato
#
#             Variety Grade Arrival_Date  Min_x0020_Price  Max_x0020_Price  \
# 0             Jyoti   FAQ   01/09/2024             2200             2700
# 1             Jyoti   FAQ   01/09/2024             2500             2700
# 2            Medium   FAQ   01/09/2024             4200             4400
# 3             Jyoti   FAQ   01/09/2024             2400             2800
# 4             Other   FAQ   01/09/2024             3000             5000
# ...             ...   ...          ...              ...              ...
# 7934          Other   FAQ   01/09/2024             7800             8200
# 7935          Other   FAQ   01/09/2024             2300             2500
# 7936        Brinjal   FAQ   01/09/2024             4700             5200
# 7937  Sweet Pumpkin   FAQ   01/09/2024             2000             2200
# 7938          Jyoti   FAQ   01/09/2024             2300             2340
#
#       Modal_x0020_Price
# 0                2500.0
# 1                2600.0
# 2                4300.0
# 3                2600.0
# 4                4000.0
# ...                 ...
# 7934             8000.0
# 7935             2400.0
# 7936             5000.0
# 7937             2000.0
# 7938             2320.0
#
# [7939 rows x 10 columns]

# %%
df['State'].value_counts().keys()
# Out:
# Index(['Tamil Nadu', 'Uttar Pradesh', 'Maharashtra', 'West Bengal',
#        'Madhya Pradesh', 'Haryana', 'Punjab', 'Kerala', 'Telangana', 'Tripura',
#        'Gujarat', 'Odisha', 'Himachal Pradesh', 'Rajasthan', 'Bihar',
#        'Chandigarh', 'Uttrakhand', 'Karnataka', 'Chattisgarh',
#        'Andhra Pradesh'],
#       dtype='object', name='State')

# %%
list(df[df['State'] == 'Andhra Pradesh'].value_counts('Commodity').keys())
# Out:
# ['Tomato']

# %%
df['Grade'] = df['Grade'].replace('FAQ', 'Other')
df.head(40)
# Out:
#                State        District                          Market  \
# 0              Bihar          Araria                      Forbesganj
# 1              Bihar      Kishanganj                     Bahadurganj
# 2              Bihar       Madhubani                        Jainagar
# 3              Bihar          Rohtas                          Natwar
# 4         Chandigarh      Chandigarh         Chandigarh(Grain/Fruit)
# 5            Gujarat          Amreli                        Damnagar
# 6            Gujarat  Chhota Udaipur                         Bodeliu
# 7            Gujarat          Rajkot       Gondal(Veg.market Gondal)
# 8            Gujarat          Rajkot       Gondal(Veg.market Gondal)
# 9            Gujarat          Rajkot       Gondal(Veg.market Gondal)
# 10           Gujarat          Rajkot       Gondal(Veg.market Gondal)
# 11           Haryana         Gurgaon                         Gurgaon
# 12           Haryana         Gurgaon                         Gurgaon
# 13           Haryana         Gurgaon                         Gurgaon
# 14           Haryana          Hissar                           Hansi
# 15           Haryana          Hissar                           Hansi
# 16           Haryana          Hissar                           Hansi
# 17           Haryana          Hissar                           Hansi
# 18           Haryana          Hissar                           Hansi
# 19           Haryana          Hissar                          Hissar
# 20           Haryana          Hissar                          Hissar
# 21           Haryana          Hissar                          Hissar
# 22           Haryana          Hissar                          Hissar
# 23           Haryana          Hissar                          Uklana
# 24           Haryana          Karnal  New Grain Market(main), Karnal
# 25           Haryana          Karnal  New Grain Market(main), Karnal
# 26           Haryana          Karnal  New Grain Market(main), Karnal
# 27           Haryana          Karnal  New Grain Market(main), Karnal
# 28           Haryana         Sonipat                          Ganaur
# 29           Haryana         Sonipat                          Ganaur
# 30           Haryana         Sonipat                          Ganaur
# 31           Haryana         Sonipat                          Ganaur
# 32           Haryana         Sonipat                          Gohana
# 33           Haryana         Sonipat                          Gohana
# 34           Haryana         Sonipat                          Gohana
# 35  Himachal Pradesh           Kullu             Kullu(Chauri Bihal)
# 36  Himachal Pradesh           Mandi                   Mandi(Takoli)
# 37  Himachal Pradesh           Mandi                   Mandi(Takoli)
# 38         Karnataka          Koppal                         Kustagi
# 39         Karnataka          Koppal                         Kustagi
#
#                   Commodity                  Variety   Grade Arrival_Date  \
# 0                    Potato                    Jyoti   Other   01/09/2024
# 1                    Potato                    Jyoti   Other   01/09/2024
# 2                     Onion                   Medium   Other   01/09/2024
# 3                    Potato                    Jyoti   Other   01/09/2024
# 4             Ginger(Green)                    Other   Other   01/09/2024
# 5         Coriander(Leaves)                Coriander   Other   01/09/2024
# 6                    Cotton  Shanker 6 (B) 30mm FIne   Other   01/09/2024
# 7                     Apple                    Apple  Medium   01/09/2024
# 8          Cucumbar(Kheera)                 Cucumbar   Other   01/09/2024
# 9              Green Chilli             Green Chilly   Other   01/09/2024
# 10                   Potato                   Potato   Other   01/09/2024
# 11              Cauliflower                    Other   Other   01/09/2024
# 12                    Onion                    Other   Other   01/09/2024
# 13              Pomegranate                    Other   Large   01/09/2024
# 14                  Brinjal                    Other   Other   01/09/2024
# 15                    Guava                    Other  Medium   01/09/2024
# 16                    Lemon                    Other   Other   01/09/2024
# 17         Ridgeguard(Tori)                    Other   Other   01/09/2024
# 18                  Spinach                    Other   Other   01/09/2024
# 19                   Banana                    Other  Medium   01/09/2024
# 20         Cucumbar(Kheera)                    Other   Other   01/09/2024
# 21                   Potato                    Other   Other   01/09/2024
# 22                  Pumpkin                    Other   Other   01/09/2024
# 23                   Tomato                    Other   Other   01/09/2024
# 24                   Banana                    Other   Large   01/09/2024
# 25                   Grapes              Annabesahai   Large   01/09/2024
# 26                    Onion                    Other   Other   01/09/2024
# 27                  Pumpkin                    Other   Other   01/09/2024
# 28         Cucumbar(Kheera)                 Cucumbar   Other   01/09/2024
# 29             Green Chilli             Green Chilly   Other   01/09/2024
# 30                    Lemon                    Lemon   Other   01/09/2024
# 31                   Tomato                   Tomato   Other   01/09/2024
# 32    Bhindi(Ladies Finger)                    Other   Other   01/09/2024
# 33                    Onion                    Other   Other   01/09/2024
# 34                   Potato                    Other   Other   01/09/2024
# 35                    Apple                    Apple  Medium   01/09/2024
# 36                  Cabbage                    Other   Other   01/09/2024
# 37                    Onion                    Other   Other   01/09/2024
# 38  Cowpea (Lobia/Karamani)           Cowpea (Whole)   Other   01/09/2024
# 39                Groundnut                    Gejje   Other   01/09/2024
#
#     Min_x0020_Price  Max_x0020_Price  Modal_x0020_Price
# 0              2200             2700             2500.0
# 1              2500             2700             2600.0
# 2              4200             4400             4300.0
# 3              2400             2800             2600.0
# 4              3000             5000             4000.0
# 5              4200             5050             4750.0
# 6              6800             7000             6900.0
# 7              6000            13000             9500.0
# 8              2000             3500             2750.0
# 9              2000             5000             3500.0
# 10              480              540              510.0
# 11             3000             5000             4000.0
# 12             2000             4000             3000.0
# 13             5000            10000             7500.0
# 14             1200             1500             1400.0
# 15             3000             3500             3300.0
# 16             5000             6000             6000.0
# 17             1500             1500             1500.0
# 18             1000             1000             1000.0
# 19             1500             1500             1500.0
# 20             2000             2200             2200.0
# 21             1800             2600             2300.0
# 22              700             1500             1200.0
# 23             2000             2000             2000.0
# 24             1500             3000             2250.0
# 25            10000            15000            12500.0
# 26             2800             4000             3400.0
# 27             1800             2000             1900.0
# 28             2500             3000             2800.0
# 29             6000             7000             6500.0
# 30            14000            15000            15000.0
# 31             3000             4000             3500.0
# 32             2000             2600             2200.0
# 33             3000             4000             3500.0
# 34             1500             2600             2500.0
# 35             1500             7000             5000.0
# 36              600             1400             1000.0
# 37             4200             4600             4500.0
# 38             7050             7860             7500.0
# 39             5950             5950             5950.0

# %%
# Feature columns and target variables
features = ['State', 'District', 'Market', 'Commodity', 'Variety', 'Grade']
target_min = 'Min_x0020_Price'
target_max = 'Max_x0020_Price'

# %%
# Splitting data into features and target
X = df[features]
y_min = df[target_min]
y_max = df[target_max]

# %%
# Categorical feature encoding
encoder = OneHotEncoder()
X_encoded = encoder.fit_transform(X)

# %%
# Train-test split
X_train, X_test, y_min_train, y_min_test, y_max_train, y_max_test = train_test_split(X_encoded, y_min, y_max, test_size=0.2, random_state=42)

# %%
# Define models
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(random_state=42),
    'Random Forest': RandomForestRegressor(n_estimators=50, random_state=12)
}

# Train and evaluate models
for name, model in models.items():
    print(f"Training and evaluating {name}...")
    
    # Train the model
    model.fit(X_train, y_min_train)
    
    print("Training Score : ",model.score(X_train,y_min_train)*100)
    print("Testing Score : ",model.score(X_test,y_min_test)*100)

    print("Training Score : ",model.score(X_train,y_max_train)*100)
    print("Testing Score : ",model.score(X_test,y_max_test)*100)
    print()
# Out:
# Training and evaluating Linear Regression...
# Training Score :  85.25133298665638
# Testing Score :  74.02227881232675
# Training Score :  82.28319718870603
# Testing Score :  73.725990874503
#
# Training and evaluating Decision Tree...
# Training Score :  100.0
# Testing Score :  70.50467511061204
# Training Score :  94.00070377751321
# Testing Score :  72.36514577219022
#
# Training and evaluating Random Forest...
# Training Score :  96.99054350639514
# Testing Score :  74.65229853252066
# Training Score :  91.75735957433315
# Testing Score :  75.35243313252504

# %%
# Choose the best model based on evaluation metrics
best_model_name = 'Random Forest'  # Replace with the model name that performed best
best_model = models[best_model_name]

# Example: Making a prediction with new data
new_data = pd.DataFrame({
    'State': ['West Bengal'], 
    'District': ['Purba Bardhaman'], 
    'Market': ['Memari'], 
    'Commodity': ['Sweet Pumpkin'], 
    'Variety': ['Sweet Pumpkin'], 
    'Grade': ['Other'], 
})

encoded_data = encoder.transform(new_data)

# Predict min and max prices
predicted_min_price = best_model.predict(encoded_data)
predicted_max_price = best_model.predict(encoded_data)

print(f'Predicted Min Price: {predicted_min_price[0]}')
print(f'Predicted Max Price: {predicted_max_price[0]}')
# Out:
# Predicted Min Price: 2120.0
# Predicted Max Price: 2120.0

# %%
os.makedirs('models',exist_ok=True)
joblib.dump(model,'./models/RandomForest.lb')
joblib.dump(encoder,'./models/Encoder.lb')
# Out:
# ['./models/Encoder.lb']

# %%
df.to_csv('Data_change.csv')
